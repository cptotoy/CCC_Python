# %%
name1 = 'john smith'
name2 = ' ALICE JOHNSON '
name3 = 'bob JONES'
raw_names= [ 'john smith',' ALICE JOHNSON ','bob JONES']

# %%
clean_data = []
for name in raw_names:
    clean_names = name.strip().title()
    clean_data.append(clean_names)
    formatted_names= "\n".join(clean_data)

print(f"Names:\n{formatted_names}")
# Out:
# Names:
# John Smith
# Alice Johnson
# Bob Jones
