# %% [markdown]
# Shopping List Manager

# %%
items = ['apples','bread','milk']

# %%
items.append('milk')
print(items)
# Out:
# ['apples', 'bread', 'milk', 'milk']

# %%
items.append('cheese')
print(items)
# Out:
# ['apples', 'bread', 'milk', 'milk', 'cheese']

# %%
items.remove('bread')
print(items)
# Out:
# ['apples', 'milk', 'milk', 'cheese']

# %%
items.insert(0,'butter')
print(items)
print(f'Total Items Count: {len(items)}')
print(f'First item: {items[0]}\nLast Item: {items[-1]}')
# Out:
# ['butter', 'butter', 'butter', 'butter', 'apples', 'milk', 'milk', 'cheese']
# Total Items Count: 8
# First item: butter
# Last Item: cheese
