# %% [markdown]
# #For each snippet below, identify: (a) error type, (b) error name, (c) fix it

# %%
#for i in range(5):
#print(i)

#errors
#IndentationError: expected an indented block after 'for' statement on line 1

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#nums = [1, 2, 3]
#print(nums[5])

#errors: 
#IndexError: list index out of range

nums = [1, 2, 3, 4, 5, 6]
print(nums[5])
# Out:
# 6

# %%
#total = 0
#for n in [5, 10, 15]:
#total = n
#print(total)

#errors:
#IndentationError: expected an indented block after 'for' statement on line 8
# +sign missing, value total not aggregating

total = 0
for n in [5, 10, 15]:
    total += n
print(total)
# Out:
# 30

# %%
#x= int('Hello')

#error
#ValueError: invalid literal for int() with base 10: 'Hello'

try:
    x = int('Hello')
except ValueError:
    print('not an integer')
# Out:
# not an integer

# %%
#if score = 100:
#print('Perfect!')

#error: 
#SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

score =100
if score == 100:
    print('Perfecty')
else:
    print('note there yet')
# Out:
# Perfecty
