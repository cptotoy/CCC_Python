# %% [markdown]
# Each program has one bug. Fix it and state the error type.

# %%
#nums = [10, 20, 30]
#Bug 1 — Wrong output (should print sum = 60):
#total = 0
#for n in nums:
#total = n
#print(f'Sum: {total}')

nums = [10, 20, 30]
total = 0
for n in nums:
    total += n
print(f'Sum: {total}')

#bug + missing
# Out:
# Sum: 60

# %%
#Bug 2 — Crashes at runtime:
scores = [85, 92, 78,56,67]
for i in range(4):
 print(scores[i])
# Out:
# 85
# 92
# 78
# 56

# %%
#Bug 3 — Wrong output (95 should be grade A):
score = 95
def get_grade(s):
    if s >= 90: 
        return 'A'
    elif s >= 80: 
        return 'B'
    elif s >= 70: 
        return 'C'
    elif s >= 60: 
        return 'D'    
print(get_grade(score))
# Out:
# A
