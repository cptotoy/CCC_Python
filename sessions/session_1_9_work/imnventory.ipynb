# %%
inventory = {'apples':50, 'bananas':30, 'oranges':45, 'grapes':0}

print(inventory['bananas'])

inventory.update({'mangoes': 25})
print(inventory)


inventory.update(apples=70)
print(inventory)

del inventory['grapes']
print(inventory)

fruit_status = inventory.get('watermelon', 'Not stocked')
print(fruit_status)

if 'oranges' in inventory:
    print("Yes, oranges are in the inventory!")
else:
    print("No oranges found.")
# Out:
# 30
# {'apples': 50, 'bananas': 30, 'oranges': 45, 'grapes': 0, 'mangoes': 25}
# {'apples': 70, 'bananas': 30, 'oranges': 45, 'grapes': 0, 'mangoes': 25}
# {'apples': 70, 'bananas': 30, 'oranges': 45, 'mangoes': 25}
# Not stocked
# Yes, oranges are in the inventory!
