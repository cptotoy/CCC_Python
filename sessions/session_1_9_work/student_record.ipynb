# %%
student = {'name': 'Alice', 'age': 20, 'gpa': 3.5, 'major': "CS", 'year': 2026, 'is_active': True}
print(student['name'])
print(student['age'])
print(student['gpa'])
print(student['major'])
print(student['year'])
print(student['is_active'])

student['email'] = 'a@a.com'

print(student['email'])

student['gpa'] = 4
print(student['gpa'])

scholarship_status = student.get('scholarship', 'Not found/Applicable')
print(scholarship_status)
    
print(f'student: {student}')
# Out:
# Alice
# 20
# 3.5
# CS
# 2026
# True
# a@a.com
# 4
# Not found/Applicable
# student: {'name': 'Alice', 'age': 20, 'gpa': 4, 'major': 'CS', 'year': 2026, 'is_active': True, 'email': 'a@a.com'}
